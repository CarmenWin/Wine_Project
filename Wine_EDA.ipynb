# %% [markdown]
# ### Project 2 Blueberry Winery EDA #####

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
red_wine = pd.read_csv('winequality-red.csv', sep=';')

display(red_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
white_wine = pd.read_csv('winequality-white.csv', sep=';')

# df = pd.read_csv('example.csv', sep=';')

display(white_wine.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %% [markdown]
# # use tail methode to show the last 10 items

# %%
display(red_wine.tail())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
display (white_wine.tail())
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# 4893     11.2        6
# ...

# %% [markdown]
# # observe for missing vaules use isna and insnull #

# %%
# Check for missing values using isna() or isnull() #sum is counting how many rows a 0 value shows 
print(red_wine.isna().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
print(white_wine.isnull().sum())
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # Use Describe to show the dataset
# # DATA WRANGLING #

# %%
print(red_wine.describe().sum()) #.sum to avoid creating giant tables
# Out:
# fixed acidity           1653.760734
# volatile acidity        1602.956880
# citric acid             1601.235777
# residual sugar          1626.048734
# chlorides               1599.996532
# free sulfur dioxide     1740.335079
# total sulfur dioxide    2095.363117
# density                 1604.982579
# pH                      1619.135500
# sulphates               1604.057656
# alcohol                 1664.588651
# quality                 1633.443592
# dtype: float64

# %%
print(red_wine.describe().sum())
# Out:
# fixed acidity           1653.760734
# volatile acidity        1602.956880
# citric acid             1601.235777
# residual sugar          1626.048734
# chlorides               1599.996532
# free sulfur dioxide     1740.335079
# total sulfur dioxide    2095.363117
# density                 1604.982579
# pH                      1619.135500
# sulphates               1604.057656
# alcohol                 1664.588651
# quality                 1633.443592
# dtype: float64

# %% [markdown]
# # creating a new label for quality in the dataset #

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
red_wine['quality_label'] = red_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
print(red_wine.describe().sum())
# Out:
# fixed acidity           1653.760734
# volatile acidity        1602.956880
# citric acid             1601.235777
# residual sugar          1626.048734
# chlorides               1599.996532
# free sulfur dioxide     1740.335079
# total sulfur dioxide    2095.363117
# density                 1604.982579
# pH                      1619.135500
# sulphates               1604.057656
# alcohol                 1664.588651
# quality                 1633.443592
# dtype: float64

# %% [markdown]
# # doing the same for the white wine data #

# %%
# we are creating a new column called "quality_label", we define a range and associate that range with a label
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 5 else 'medium'
if value <= 7 else 'high')
print(white_wine.describe().sum())
# Out:
# fixed acidity           4944.098656
# volatile acidity        4900.349036
# citric acid             4901.095211
# residual sugar          4992.663473
# chlorides               4898.551620
# free sulfur dioxide     5344.315222
# total sulfur dioxide    5936.858722
# density                 4904.004671
# pH                      4917.429267
# sulphates               4901.333973
# alcohol                 4963.244888
# quality                 4933.763548
# dtype: float64

# %% [markdown]
# # here we are transforming these labels into categrical data type (specific to pandas) instead of simple string

# %%
red_wine['quality_label'] = pd.Categorical(red_wine['quality_label'],
categories=['low', 'medium', 'high'])
display (red_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %% [markdown]
# # the same now for white wine #

# %%
white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])
display (white_wine)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# # Using Concatenate to merge red and white wine list #

# %%
def new_func():
    pd.concat([red_wine.describe(), white_wine.describe()])
    axis = 1, keys == (["Red Wine Stats, White Wine Stats"])
    sns.set(rc = {'figure.figsize':(15,8)})
    print ()

# %% [markdown]
# # Obeservations from comparing red vs white wine # (comparing the mean)
#
# - White wine has much more residual sugar than red wine
# - white wine has higher free sulfur dioxide
# - red wine is higher in sulphates
# - alcohol does not give us much variation to distinguish whether the vine is white or red, but it makes a lot of difference in quality. Note that the higher the quality the higher the average alcohol concentration, increased by about 1% at each level. Although lower quality wines have the lowest standard deviation.
# - The chlorides and volatile acidity are less present and presented smaller standard deviation in wines of higher quality.
# - The free sulfur dioxide is higher with higher quality, but their standard deviation decrease with the increase the quality.
# - Higher quality has less fixed acidity, but the standard deviation is slightly higher in mean quality

# %% [markdown]
# # Pie Chart comparing quantity of Red and White Wine #

# %% [markdown]
# # Using the seaborn histplot to create another plot #
# # compare red and white wine in comparison to distribution quality levels #

# %% [markdown]
# different way to create teh pie chart

# %%
# Get the count of each wine type
red_wine_count = len(red_wine)
white_wine_count = len(white_wine)

# Create a list of counts for each wine type
counts = [red_wine_count, white_wine_count]

# Define the labels for the pie chart
labels = ['Red Wine', 'White Wine']

# Define the colors for each wedge in the pie chart
colors = ['#ff4444', '#66b3ff']

# Create the pie chart
plt.pie(counts, labels=labels, colors=colors, autopct='%1.1f%%')

# Add a title
plt.title('Proportion of Red Wine and White Wine in Dataset')

# Show the plot
plt.show()

# %%
fig = plt.figure(figsize = (18, 4))
title = fig.suptitle("Wine Type Vs Quality", fontsize=14)
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(1,4, 1)
ax1.set_title("Red Wine")
ax1.set_xlabel("Quality")
ax1.set_ylabel("Frequency") 
rw_q = wines.quality[wines.type == 'red'].value_counts()
rw_q = (list(rw_q.index), list(rw_q.values))

ax1.set_ylim([0, 2500])
ax1.tick_params(axis='both', which='major', labelsize=8.5)
bar1 = ax1.bar(rw_q[0], rw_q[1], color='red', edgecolor='black', linewidth=1)
ax2 = fig.add_subplot(1,4, 2)
ax2.set_title("White Wine")
ax2.set_xlabel("Quality")
ax2.set_ylabel("Frequency") 
ww_q = wines.quality[wines.type == 'white'].value_counts()
ww_q = (list(ww_q.index), list(ww_q.values))
ax2.set_ylim([0, 2500])
ax2.tick_params(axis='both', which='major', labelsize=8.5)
bar2 = ax2.bar(ww_q[0], ww_q[1], color='white', edgecolor='black', linewidth=1)

# %%
white_wine.shape

sns.set_style ('darkgrid')
sns.histplot (white_wine.alcohol)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.boxplot (x="quality", y="pH", data = red_wine)
plt.title ('Quality and pH in Red Wine')

# Show the plot
plt.show()

# %%
#https://www.youtube.com/watch?v=Vo-bfTqEFQk

sns.boxplot (x="quality", y="pH", data = white_wine)
plt.title ('Quality and pH in White Wine')

# Show the plot
plt.show()

# %%
sns.boxplot (x="quality", y="alcohol", data = white_wine, palette = "copper") # Palette change  the color 
plt.title ('Quality and Alcohol Content in White Wine')

# Show the plot
plt.show()
#this color is not working on a screen....

# %%
sns.boxplot (x="quality", y="alcohol", data = red_wine, palette = "copper") # Palette change  the color 
plt.title ('Quality and Alcohol Content in Red Wine')

# Show the plot
plt.show()

# %% [markdown]
# # histplot with Seaborn #
# using sns lmplot with regression line

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.colors as mcolors

# %%
sns.lmplot(red_wine, x='residual sugar', y= 'alcohol', palette = 'red') #no change in color, why?????
plt.title('Red Wine Correlation Alcohol vs Residual Sugar')
plt.show ()

# %%
sns.lmplot(white_wine, x='chlorides', y= 'alcohol')
plt.title('Correlation Alcohol vs Chlorides')
# Out:
# Text(0.5, 1.0, 'Correlation Alcohol vs Chlorides')

# %% [markdown]
# # using Scatterplot to compare date #

# %%
sns.set_style ('white') 
plt.title('Quality of White Wine')
sns.scatterplot (white_wine.quality)

sns.set_style ('white')
plt.title ('Quality of Red and White Wine')
sns.scatterplot (red_wine.quality, color = "red")
plt.xlabel('Number of Wines')
plt.show()

# %% [markdown]
# # compare red and white wine using heatmap with correlation

# %%
white_wine.corr
sns.heatmap (white_wine.corr (), cmap = "Blues", annot=True, fmt='.0f')
sns.set(rc = {'figure.figsize':(15,8)}) #makes plot appear bigger (copied from LMS)
#using onlye one color fmt =.Of= only shows integers, if I don't want more decimal points
plt.title ('Correlation White Wine')
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_2954/3670102693.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap (white_wine.corr (), cmap = "Blues", annot=True, fmt='.0f')
# Text(0.5, 1.0, 'Correlation White Wine')

# %% [markdown]
# Second Heatmap for White wine with decimal points (more useful for statistical analysis)

# %%
white_wine.corr
sns.heatmap (white_wine.corr (), cmap = "Blues", annot=True)
sns.set(rc = {'figure.figsize':(15,8)}) #makes plot appear bigger (copied from LMS)
#using onlye one color fmt =.Of= only shows integers, if I don't want more decimal points
plt.title ('Correlation White Wine')
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_2954/1981485517.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap (white_wine.corr (), cmap = "Blues", annot=True)
# Text(0.5, 1.0, 'Correlation White Wine')

# %%
red_wine.corr
sns.heatmap (red_wine.corr (), cmap = "Blues", annot=True, fmt='.0f')
sns.set(rc = {'figure.figsize':(15,8)}) #makes plot appear bigger (copied from LMS)
#using onlye one color fmt =.Of= only shows integers, if I don't want more decimal points
plt.title ('Correlation Red Wine')
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_2954/127175952.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap (red_wine.corr (), cmap = "Blues", annot=True, fmt='.0f')
# Text(0.5, 1.0, 'Correlation Red Wine')

# %% [markdown]
# Also for Red wine the heatmap with decimal points for better analysis

# %%
red_wine.corr
sns.heatmap (red_wine.corr (), cmap = "Blues", annot=True)
sns.set(rc = {'figure.figsize':(15,8)}) #makes plot appear bigger (copied from LMS)
#using onlye one color fmt =.Of= only shows integers, if I don't want more decimal points
plt.title ('Correlation Red Wine')
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_2954/2758557209.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap (red_wine.corr (), cmap = "Blues", annot=True)
# Text(0.5, 1.0, 'Correlation Red Wine')

# %% [markdown]
# # Create boxplot see LMS #
#
# The wine alcohol by volume distribution has an increasing trend based on higher quality rated wine samples, some outliers in each quality level

# %%
sns.boxplot (x= "quality", y= "pH", data = white_wine);
plt.title ("White Wine Quality Alcohol Content")
# Out:
# Text(0.5, 1.0, 'White Wine Quality Alcohol Content')

# %%
sns.boxplot (x= "quality", y= "alcohol", data = white_wine);
plt.title ("White Wine Quality Alcohol Content")
# Out:
# Text(0.5, 1.0, 'White Wine Quality Alcohol Content')

# %% [markdown]
# # Violinplot = categorical distribution plot, much alike to the boxplot
# https://www.youtube.com/watch?v=PNNLefP974M

# %%
data = combined_wine
sns.violinplot(x="quality", y="alcohol", hue="type", data = combined_wine)
#ugly change it!! Was trying to show it as one big combined violine plot....
inner = "quartiles"

# %% [markdown]
# boxplots for red and white wine. It is hard to interpret them, try something else

# %%
sns.catplot (y="alcohol", x= "quality", data = red_wine, hue = "pH");
sns.set(rc = {'figure.figsize':(16,9)})
plt.title ("Alcohol Content Red Wine")

# %%
sns.catplot (y="alcohol", x= "quality", data = white_wine, hue = "pH", color = "orange");
sns.set(rc = {'figure.figsize':(15,8)})
plt.title ("Alcohol Content White Wine")
# Out:
# /Users/CW/anaconda3/envs/CodeAcademy/lib/python3.11/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:orange'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Alcohol Content White Wine')

# %%
sns.catplot (y="alcohol", x= "quality", data = red_wine, hue = "pH", color = "red");
sns.set (rc = {'figure.figsize':(15,8)})
plt.title ("Alcohol Content Red Wine")
# Out:
# /Users/CW/anaconda3/envs/CodeAcademy/lib/python3.11/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:red'` for same effect.
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Alcohol Content Red Wine')

# %% [markdown]
# # Sprint 2#

# %%
sns.set_style ('darkgrid')
sns.histplot (x = "residual sugar", data = white_wine, palette = "blue");
plt.title ("Residual Sugar Content in White Wine")
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_3290/1486996652.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot (x = "residual sugar", data = white_wine, palette = "blue");
# Text(0.5, 1.0, 'Residual Sugar Content in White Wine')

# %% [markdown]
# # see LMS, second chart recreated, this time for red wine #

# %%
sns.set_style ('whitegrid')
sns.histplot (x = "residual sugar", data = red_wine);
plt.title ("Residual Sugar Content in Red Wine")

# the graphs are different but we cannot easily compare them because the x and y axis are differently labeled, how to fix that?
# Out:
# Text(0.5, 1.0, 'Residual Sugar Content in Red Wine')

# %% [markdown]
# # Sprint 2, another graph sulphates and red wine, Histogram

# %%
sns.set_style ('whitegrid')
sns.histplot (x = "sulphates", data = red_wine);
plt.tick_params(axis='both', which='both', color='red') # this is supposed to change the color, it did not work 
plt.title ("Red Wine Sulphates Quality")
plt.show ()

# %% [markdown]
# # Sprint 2 Making a jointplot, see LMS #
#
# red wine samples have higher acidity as compared to its white wine counterparts. Also we can see an overall decrease in acidity with higher quality wine for red wine samples but not so much for white wine samples

# %% [markdown]
# Red wine samples have higher acidity as compared to its white wine counterparts. Also, overall decrease in acidity with higher quality wine for red wine samples but not so much for white wine samples

# %%
data = white_wine
sns.jointplot(data=white_wine, x='quality', y='sulphates', color = "orange")
kind='reg' # Regeression Line is not showing#
plt.title ("White Wine Sulphates Quality", y = 1.2) # title was overlapping with graph, by adding y= 1.2 it got fixed !
# Out:
# Text(0.5, 1.2, 'White Wine Sulphates Quality')

# %% [markdown]
# same now for the red wine

# %%
data = red_wine
sns.jointplot(data=red_wine, x='quality', y='sulphates', color = "red")
kind='reg' # Regeression Line is not showing#
plt.title ("Red Wine Sulphates Quality", y = 1.2) # title was overlapping with graph, by adding y= 1.2 it got fixed !
# the y axis is different than for the white wine, it makes the results looking distorted when comparing them for the presentation
# Out:
# Text(0.5, 1.2, 'Red Wine Sulphates Quality')

# %% [markdown]
# # Sprint 2, See LMS, Scatterplot Sulphates, Alcohol and quality

# %%
sns.scatterplot (x= "alcohol", y= "sulphates", hue = "quality", data = red_wine, palette = "Reds") 
plt.title ("Red Wines, Sulphates, Alcohol, Quality")
plt.legend(title='Quality', loc='upper right', labels=['low', 'medium', 'high'])

# %% [markdown]
# # same plot for white wine #

# %%
sns.scatterplot (x= "alcohol", y= "sulphates", hue = "quality", data = white_wine, palette = "Accent") 
plt.legend(title='Quality', loc='upper right', labels=['low', 'medium', 'high']) #added a legend

plt.title ("White Wines, Sulphates, Alcohol, Quality")
# Out:
# Text(0.5, 1.0, 'White Wines, Sulphates, Alcohol, Quality')

# %% [markdown]
# # Sprint 2 watch video and create more plots # Graph was created by copying code from sprint 2 Univariate Analysis

# %%
red_wine.hist(bins=15, color='red', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('Red Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %% [markdown]
# # Univariate Analysis of White wine

# %%
white_wine.hist(bins=15, color='yellow', edgecolor='black', linewidth=1.0, xlabelsize=8, ylabelsize=8, grid=False)

plt.tight_layout(rect=(0, 0, 1.2, 1.2))

rt = plt.suptitle('White Wine Univariate Plots', x=0.65, y=1.25, fontsize=15)

# %% [markdown]
# # Violin Plot #

# %%
data = white_wine 
data = red_wine

# add a new column to each dataset indicating the type of wine
white_wine['type'] = 'white'
red_wine['type'] = 'red'


# Combine the data into one dataframe
combined_wine = pd.concat([red_wine, white_wine])

# Create the violinplot
sns.violinplot(x='quality', y='alcohol', hue='type', data=combined_wine, split=True)

# Add labels and title
plt.xlabel('Quality')
plt.ylabel('Alcohol')
plt.title('Combined Violinplot of Red and White Wine')  
plt.show()

# %% [markdown]
# # finding more points to compare red and white wine

# %%
sns.scatterplot (x= "alcohol", y= "volatile acidity", hue = "quality", data = white_wine, palette = "Accent") 
plt.legend(title='Quality', loc='upper right', labels=['low', 'medium', 'high']) #added a legend

plt.title ("White Wines, Acidity Alcohol, Quality")
# Out:
# Text(0.5, 1.0, 'White Wines, Acidity Alcohol, Quality')

# %% [markdown]
# Red wine samples have higher acidity as compared to its white wine. Overall decrease in acidity with higher quality wine for red wine samples but not so much for white wine samples.

# %%
sns.scatterplot (x= "alcohol", y= "sulphates", hue = "quality", data = red_wine, palette = "Reds") 
plt.legend(title='Quality', loc='upper right', labels=['low', 'medium', 'high']) #added a legend

plt.title ("Red Wines, Sulphates, Alcohol, Quality")
# Out:
# Text(0.5, 1.0, 'Red Wines, Sulphates, Alcohol, Quality')

# %% [markdown]
# more comparison between different variables and quality

# %%
# add a new column to each dataset indicating the type of wine
white_wine['type'] = 'white'
red_wine['type'] = 'red'

# Combine the data into one dataframe
combined_wine = pd.concat([red_wine, white_wine])

# %%
combined_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Create Jointplot 

sns.jointplot(data = combined_wine, x='quality', y='sulphates')
plt.tight_layout()
plt.title("Red and White Wine")

# %%
# Add a new column to each dataset indicating the type of wine
white_wine['type'] = 'white'
red_wine['type'] = 'red'

# Combine the data into one dataframe
combined_wine = pd.concat([red_wine, white_wine])

# Create Jointplot 
sns.jointplot(x='quality', y='sulphates', data=combined_wine)
plt.title("Red and White Wine")
plt.tight_layout()
plt.show()

# %% [markdown]
# Statistical Analysis for the White/Red Wine

# %% [markdown]
# Correlation based on Wine quality labels

# %%
wines = pd.concat([white_wine, red_wine], axis=0)

# Compute correlation matrix
corr_matrix = wines.corr()

# Create heatmap
sns.heatmap(corr_matrix, cmap="coolwarm")

# Show plot
plt.show()
# Out:
# /var/folders/28/lqytsck570bbnwy7thfhf1m40000gn/T/ipykernel_20725/299145095.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = wines.corr()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Volatile Acidity', fontsize=14)

sns.violinplot(x='quality', y='volatile acidity', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Volatile Acidity",size = 12,alpha=0.8)

sns.violinplot(x='quality_label', y='volatile acidity', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Volatile Acidity",size = 12,alpha=0.8)
plt.figure(figsize=(11, 9))
plt.show()

# %% [markdown]
# check for citric acidity (according to the heatmap, there should be a high correlation between quality and citric acidity)

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Citric Acid', fontsize=14)

sns.violinplot(x='quality', y='citric acid', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Citric Acid",size = 12,alpha=0.8)

sns.violinplot(x='quality_label', y='citric acid', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Citric Acid",size = 12,alpha=0.8)
plt.figure(figsize=(11, 9))
plt.show()

# %% [markdown]
# same now for Fixed Acidity

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Fixed Acidity', fontsize=14)

sns.violinplot(x='quality', y='fixed acidity', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Volatile Acidity",size = 12,alpha=0.8)

sns.violinplot(x='quality_label', y='fixed acidity', hue='type', data=wines, split=True, inner='quart', linewidth=1.3,
               palette={'red': '#FF9999', 'white': 'white'}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Fixed Acidity",size = 12,alpha=0.8)
plt.figure(figsize=(11, 9))
plt.show()

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 4))
f.suptitle('Wine Type - Quality - Alcohol Content', fontsize=14)

sns.boxplot(x='quality', y='alcohol', hue='type', data=combined_wine, palette={"red": "#FF9999", "white": "white"}, ax=ax1)
ax1.set_xlabel("Wine Quality",size = 12,alpha=0.8)
ax1.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)

sns.boxplot(x='quality_label', y='alcohol', hue='type', data=combined_wine, palette={"red": "#FF9999", "white": "white"}, ax=ax2)
ax2.set_xlabel("Wine Quality Class",size = 12,alpha=0.8)
ax2.set_ylabel("Wine Alcohol %",size = 12,alpha=0.8)
plt.figure(figsize=(11, 9))
plt.show()
